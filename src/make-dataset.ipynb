# %% [markdown]
# ### Import libs

# %%
import json
import pandas as pd
import cv2
import numpy as np
import argparse

# %%
import os
os.environ["OPENCV_FFMPEG_CAPTURE_OPTIONS"] = "rtsp_transport;udp"

# %% [markdown]
# ### Extract face frames from video files

# %%
face_cascade = cv2.CascadeClassifier('models/haarcascades/haarcascade_frontalface_alt.xml')


def detect_faces(frame):
    frame_gray = cv2.equalizeHist(frame)
    faces = face_cascade.detectMultiScale(frame_gray)
    return faces
 
def get_faces_from_video_file(file_path, fake):

    cap = cv2.VideoCapture(file_path)
    file_name = file_path.split('/')[-1]

    frame_values = [80 ,100, 150, 200]
    #frame_values = [200]

    for frame_number in frame_values:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number);
        ret, frame = cap.read()
        
        cv2.imshow(f'img-{frame_number}', frame)
        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = detect_faces(gray)
        
#         print(faces)
#         print(len(faces))
        
        if faces is not None and len(faces) > 0:
            for (x,y,w,h) in faces:
                faceROI = frame[y:y+h,x:x+w]
                cv2.imshow(f'face-{frame_number}', faceROI)
                
            ### gets only the last face found
            #cv2.imshow(f'frame-{frame_number}', faceROI)
            #cv2.imwrite(file_path.replace(".mp4","") + f'-f{frame_number}.jpg',frame)
            cv2.imwrite(f'data/{fake}/{file_name}-f{frame_number}.jpg',faceROI)

        else:
            print(f'face not found for file {file_path}, frame {frame_number}')
            
    cv2.waitKey()

# %%
data_path = 'deepfake-detection-challenge-data/'

with open(f'{data_path}metadata.json') as json_file:
    data = json.load(json_file)

# %%
# real_path = 'data/real/'
# fake_path = 'data/fake/'

for key in data.keys():
    file_name = key
    fake = data[key]['label'].lower()
    print('extracting images for file',file_name,':',fake)
    get_faces_from_video_file(data_path + file_name, fake)
# Out:
# extracting images for file aagfhgtpmv.mp4 : fake
# extracting images for file aapnvogymq.mp4 : fake
# extracting images for file abarnvbtwb.mp4 : real
# extracting images for file abofeumbvv.mp4 : fake
# extracting images for file abqwwspghj.mp4 : fake
# extracting images for file acifjvzvpm.mp4 : fake
# extracting images for file acqfdwsrhi.mp4 : fake
# extracting images for file acxnxvbsxk.mp4 : fake
# extracting images for file acxwigylke.mp4 : fake
# extracting images for file aczrgyricp.mp4 : fake
# extracting images for file adhsbajydo.mp4 : fake
# face not found for file deepfake-detection-challenge-data/adhsbajydo.mp4, frame 80
# extracting images for file adohikbdaz.mp4 : fake
# extracting images for file adylbeequz.mp4 : fake
# face not found for file deepfake-detection-challenge-data/adylbeequz.mp4, frame 200
# extracting images for file aelfnikyqj.mp4 : real
# extracting images for file aelzhcnwgf.mp4 : fake
# extracting images for file aettqgevhz.mp4 : fake
# extracting images for file aevrfsexku.mp4 : fake
# extracting images for file afoovlsmtx.mp4 : real
# extracting images for file agdkmztvby.mp4 : fake
# extracting images for file agqphdxmwt.mp4 : fake
# face not found for file deepfake-detection-challenge-data/agqphdxmwt.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/agqphdxmwt.mp4, frame 150
# extracting images for file agrmhtjdlk.mp4 : real
# extracting images for file ahbweevwpv.mp4 : fake
# extracting images for file ahdbuwqxit.mp4 : fake
# extracting images for file ahfazfbntc.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ahfazfbntc.mp4, frame 150
# extracting images for file ahqqqilsxt.mp4 : real
# extracting images for file aipfdnwpoo.mp4 : fake
# extracting images for file ajqslcypsw.mp4 : real
# extracting images for file ajwpjhrbcv.mp4 : fake
# extracting images for file aklqzsddfl.mp4 : fake
# extracting images for file aknbdpmgua.mp4 : fake
# extracting images for file aknmpoonls.mp4 : fake
# extracting images for file akvmwkdyuv.mp4 : fake
# extracting images for file akxoopqjqz.mp4 : fake
# face not found for file deepfake-detection-challenge-data/akxoopqjqz.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/akxoopqjqz.mp4, frame 100
# extracting images for file akzbnazxtz.mp4 : fake
# extracting images for file aladcziidp.mp4 : fake
# extracting images for file alaijyygdv.mp4 : fake
# extracting images for file alninxcyhg.mp4 : fake
# face not found for file deepfake-detection-challenge-data/alninxcyhg.mp4, frame 100
# extracting images for file altziddtxi.mp4 : fake
# face not found for file deepfake-detection-challenge-data/altziddtxi.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/altziddtxi.mp4, frame 100
# extracting images for file alvgwypubw.mp4 : fake
# extracting images for file amaivqofda.mp4 : fake
# extracting images for file amowujxmzc.mp4 : fake
# extracting images for file andaxzscny.mp4 : fake
# extracting images for file aneclqfpbt.mp4 : fake
# face not found for file deepfake-detection-challenge-data/aneclqfpbt.mp4, frame 150
# extracting images for file anpuvshzoo.mp4 : real
# face not found for file deepfake-detection-challenge-data/anpuvshzoo.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/anpuvshzoo.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/anpuvshzoo.mp4, frame 200
# extracting images for file aorjvbyxhw.mp4 : fake
# extracting images for file apatcsqejh.mp4 : fake
# face not found for file deepfake-detection-challenge-data/apatcsqejh.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/apatcsqejh.mp4, frame 200
# extracting images for file apgjqzkoma.mp4 : fake
# extracting images for file apogckdfrz.mp4 : fake
# face not found for file deepfake-detection-challenge-data/apogckdfrz.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/apogckdfrz.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/apogckdfrz.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/apogckdfrz.mp4, frame 200
# extracting images for file aqpnvjhuzw.mp4 : fake
# extracting images for file arkroixhey.mp4 : fake
# extracting images for file arlmiizoob.mp4 : fake
# face not found for file deepfake-detection-challenge-data/arlmiizoob.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/arlmiizoob.mp4, frame 100
# extracting images for file arrhsnjqku.mp4 : fake
# extracting images for file asaxgevnnp.mp4 : real
# extracting images for file asdpeebotb.mp4 : fake
# extracting images for file aslsvlvpth.mp4 : fake
# face not found for file deepfake-detection-challenge-data/aslsvlvpth.mp4, frame 150
# extracting images for file asmpfjfzif.mp4 : fake
# face not found for file deepfake-detection-challenge-data/asmpfjfzif.mp4, frame 100
# extracting images for file asvcrfdpnq.mp4 : fake
# extracting images for file atkdltyyen.mp4 : real
# extracting images for file atvmxvwyns.mp4 : real
# extracting images for file atxvxouljq.mp4 : fake
# extracting images for file atyntldecu.mp4 : fake
# face not found for file deepfake-detection-challenge-data/atyntldecu.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/atyntldecu.mp4, frame 200
# extracting images for file atzdznmder.mp4 : fake
# face not found for file deepfake-detection-challenge-data/atzdznmder.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/atzdznmder.mp4, frame 100
# extracting images for file aufmsmnoye.mp4 : fake
# extracting images for file augtsuxpzc.mp4 : fake
# extracting images for file avfitoutyn.mp4 : fake
# face not found for file deepfake-detection-challenge-data/avfitoutyn.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/avfitoutyn.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/avfitoutyn.mp4, frame 200
# extracting images for file avgiuextiz.mp4 : fake
# face not found for file deepfake-detection-challenge-data/avgiuextiz.mp4, frame 200
# extracting images for file avibnnhwhp.mp4 : fake
# face not found for file deepfake-detection-challenge-data/avibnnhwhp.mp4, frame 150
# extracting images for file avmjormvsx.mp4 : real
# extracting images for file avnqydkqjj.mp4 : fake
# extracting images for file avssvvsdhz.mp4 : fake
# extracting images for file avtycwsgyb.mp4 : fake
# face not found for file deepfake-detection-challenge-data/avtycwsgyb.mp4, frame 100
# extracting images for file avvdgsennp.mp4 : fake
# extracting images for file avywawptfc.mp4 : fake
# extracting images for file awhmfnnjih.mp4 : fake
# extracting images for file awnwkrqibf.mp4 : fake
# extracting images for file awukslzjra.mp4 : fake
# extracting images for file axczxisdtb.mp4 : fake
# face not found for file deepfake-detection-challenge-data/axczxisdtb.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/axczxisdtb.mp4, frame 100
# extracting images for file axntxmycwd.mp4 : real
# face not found for file deepfake-detection-challenge-data/axntxmycwd.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/axntxmycwd.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/axntxmycwd.mp4, frame 200
# extracting images for file axoygtekut.mp4 : fake
# extracting images for file axwgcsyphv.mp4 : fake
# extracting images for file axwovszumc.mp4 : fake
# face not found for file deepfake-detection-challenge-data/axwovszumc.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/axwovszumc.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/axwovszumc.mp4, frame 200
# extracting images for file aybgughjxh.mp4 : real
# extracting images for file aybumesmpk.mp4 : real
# extracting images for file ayqvfdhslr.mp4 : fake
# extracting images for file aytzyidmgs.mp4 : real
# face not found for file deepfake-detection-challenge-data/aytzyidmgs.mp4, frame 150
# extracting images for file azpuxunqyo.mp4 : fake
# extracting images for file azsmewqghg.mp4 : fake
# extracting images for file bahdpoesir.mp4 : fake
# extracting images for file bbhpvrmbse.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bbhpvrmbse.mp4, frame 200
# extracting images for file bbhtdfuqxq.mp4 : fake
# extracting images for file bbvgxeczei.mp4 : fake
# extracting images for file bchnbulevv.mp4 : fake
# extracting images for file bctvsmddgq.mp4 : fake
# extracting images for file bdbhekrrwo.mp4 : fake
# extracting images for file bddjdhzfze.mp4 : real
# extracting images for file bdgipnyobr.mp4 : fake
# extracting images for file bdnaqemxmr.mp4 : real
# extracting images for file bdxuhamuqx.mp4 : fake
# extracting images for file beboztfcme.mp4 : real
# extracting images for file bejhvclboh.mp4 : real
# face not found for file deepfake-detection-challenge-data/bejhvclboh.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/bejhvclboh.mp4, frame 200
# extracting images for file benmsfzfaz.mp4 : fake
# face not found for file deepfake-detection-challenge-data/benmsfzfaz.mp4, frame 200
# extracting images for file beyebyhrph.mp4 : real
# extracting images for file bffwsjxghk.mp4 : real
# extracting images for file bgaogsjehq.mp4 : fake
# extracting images for file bggsurpgpr.mp4 : fake
# extracting images for file bghphrsfxf.mp4 : fake
# extracting images for file bgmlwsoamc.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bgmlwsoamc.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bgmlwsoamc.mp4, frame 200
# extracting images for file bguwlyazau.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bguwlyazau.mp4, frame 150
# extracting images for file bgvhtpzknn.mp4 : real
# face not found for file deepfake-detection-challenge-data/bgvhtpzknn.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bgvhtpzknn.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/bgvhtpzknn.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/bgvhtpzknn.mp4, frame 200
# extracting images for file bgwmmujlmc.mp4 : real
# extracting images for file bhaaboftbc.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bhaaboftbc.mp4, frame 80
# extracting images for file bhbdugnurr.mp4 : fake
# extracting images for file bhpwpydzpo.mp4 : fake
# extracting images for file bhsluedavd.mp4 : fake
# extracting images for file bilnggbxgu.mp4 : real
# extracting images for file bjjbwsqjir.mp4 : fake
# extracting images for file bjkmjilrxp.mp4 : fake
# extracting images for file bjsmaqefoi.mp4 : fake
# extracting images for file bkmdzhfzfh.mp4 : fake
# extracting images for file bkvetcojbt.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bkvetcojbt.mp4, frame 80
# extracting images for file bkwxhglwct.mp4 : fake
# extracting images for file blpchvmhxx.mp4 : fake
# face not found for file deepfake-detection-challenge-data/blpchvmhxx.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/blpchvmhxx.mp4, frame 150
# extracting images for file blzydqdfem.mp4 : fake
# extracting images for file bmbbkwmxqj.mp4 : fake
# extracting images for file bmehkyanbj.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bmehkyanbj.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bmehkyanbj.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/bmehkyanbj.mp4, frame 150
# extracting images for file bmhvktyiwp.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bmhvktyiwp.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bmhvktyiwp.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/bmhvktyiwp.mp4, frame 200
# extracting images for file bmioepcpsx.mp4 : fake
# extracting images for file bmjmjmbglm.mp4 : fake
# extracting images for file bmjzrlszhi.mp4 : real
# extracting images for file bnbuonyoje.mp4 : fake
# extracting images for file bndybcqhfr.mp4 : fake
# extracting images for file bnjcdrfuov.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bnjcdrfuov.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/bnjcdrfuov.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/bnjcdrfuov.mp4, frame 200
# extracting images for file bntlodcfeg.mp4 : fake
# extracting images for file bofqajtwve.mp4 : fake
# extracting images for file boovltmuwi.mp4 : fake
# extracting images for file bopqhhalml.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bopqhhalml.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bopqhhalml.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/bopqhhalml.mp4, frame 150
# extracting images for file bourlmzsio.mp4 : fake
# extracting images for file bpapbctoao.mp4 : real
# extracting images for file bpwzipqtxf.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bpwzipqtxf.mp4, frame 80
# extracting images for file bpxckdzddv.mp4 : fake
# extracting images for file bqdjzqhcft.mp4 : fake
# extracting images for file bqeiblbxtl.mp4 : fake
# extracting images for file bqhtpqmmqp.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bqhtpqmmqp.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bqhtpqmmqp.mp4, frame 100
# extracting images for file bqkdbcqjvb.mp4 : fake
# extracting images for file bqnymlsayl.mp4 : fake
# extracting images for file bqqpbzjgup.mp4 : fake
# extracting images for file bqtuuwzdtr.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bqtuuwzdtr.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/bqtuuwzdtr.mp4, frame 200
# extracting images for file brhalypwoo.mp4 : fake
# face not found for file deepfake-detection-challenge-data/brhalypwoo.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/brhalypwoo.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/brhalypwoo.mp4, frame 150
# extracting images for file brvqtabyxj.mp4 : fake
# extracting images for file brwrlczjvi.mp4 : real
# extracting images for file bseamdrpbj.mp4 : fake
# extracting images for file bsfmwclnqy.mp4 : fake
# extracting images for file bsqgziaylx.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bsqgziaylx.mp4, frame 80
# extracting images for file btiysiskpf.mp4 : fake
# extracting images for file btjlfpzbdu.mp4 : fake
# extracting images for file btjwbtsgln.mp4 : fake
# extracting images for file btmsngnqhv.mp4 : fake
# extracting images for file btohlidmru.mp4 : fake
# extracting images for file btugrnoton.mp4 : fake
# extracting images for file btunxncpjh.mp4 : fake
# extracting images for file btxlttbpkj.mp4 : fake
# extracting images for file bulkxhhknf.mp4 : real
# extracting images for file bvgwelbeof.mp4 : fake
# extracting images for file bvzjkezkms.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bvzjkezkms.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bvzjkezkms.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/bvzjkezkms.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/bvzjkezkms.mp4, frame 200
# extracting images for file bweezhfpzp.mp4 : fake
# extracting images for file bwhlgysghg.mp4 : real
# extracting images for file bwipwzzxxu.mp4 : real
# extracting images for file bwuwstvsbw.mp4 : fake
# extracting images for file bxzakyopjf.mp4 : real
# extracting images for file bydaidkpdp.mp4 : fake
# extracting images for file byfenovjnf.mp4 : fake
# extracting images for file byijojkdba.mp4 : fake
# extracting images for file byofowlkki.mp4 : fake
# extracting images for file byqzyxifza.mp4 : fake
# extracting images for file byunigvnay.mp4 : fake
# face not found for file deepfake-detection-challenge-data/byunigvnay.mp4, frame 80
# extracting images for file byyqectxqa.mp4 : fake
# extracting images for file bzmdrafeex.mp4 : fake
# face not found for file deepfake-detection-challenge-data/bzmdrafeex.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/bzmdrafeex.mp4, frame 100
# extracting images for file bzythlfnhq.mp4 : real
# extracting images for file caifxvsozs.mp4 : real
# extracting images for file caqbrkogkb.mp4 : fake
# extracting images for file cbbibzcoih.mp4 : fake
# extracting images for file cbltdtxglo.mp4 : fake
# extracting images for file ccfoszqabv.mp4 : real
# extracting images for file ccmonzqfrz.mp4 : fake
# extracting images for file cdaxixbosp.mp4 : fake
# extracting images for file cdbsbdymzd.mp4 : fake
# extracting images for file cdphtzqrvp.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cdphtzqrvp.mp4, frame 200
# extracting images for file cdyakrxkia.mp4 : fake
# extracting images for file cepxysienc.mp4 : fake
# extracting images for file cettndmvzl.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cettndmvzl.mp4, frame 200
# extracting images for file ceymbecxnj.mp4 : fake
# extracting images for file cferslmfwh.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cferslmfwh.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/cferslmfwh.mp4, frame 150
# extracting images for file cffffbcywc.mp4 : fake
# extracting images for file cfxkpiweqt.mp4 : real
# extracting images for file cfyduhpbps.mp4 : fake
# extracting images for file cglxirfaey.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cglxirfaey.mp4, frame 200
# extracting images for file cgvrgibpfo.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cgvrgibpfo.mp4, frame 150
# extracting images for file chtapglbcj.mp4 : real
# extracting images for file chviwxsfhg.mp4 : real
# face not found for file deepfake-detection-challenge-data/chviwxsfhg.mp4, frame 200
# extracting images for file chzieimrwu.mp4 : fake
# extracting images for file ciyoudyhly.mp4 : real
# face not found for file deepfake-detection-challenge-data/ciyoudyhly.mp4, frame 100
# extracting images for file cizlkenljw.mp4 : real
# face not found for file deepfake-detection-challenge-data/cizlkenljw.mp4, frame 200
# extracting images for file ckbdwedgmc.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ckbdwedgmc.mp4, frame 200
# extracting images for file ckjaibzfxa.mp4 : real
# extracting images for file ckkuyewywx.mp4 : real
# face not found for file deepfake-detection-challenge-data/ckkuyewywx.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/ckkuyewywx.mp4, frame 150
# extracting images for file cknyxaqouy.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cknyxaqouy.mp4, frame 150
# extracting images for file cksanfsjhc.mp4 : fake
# extracting images for file clihsshdkq.mp4 : fake
# extracting images for file clrycekyst.mp4 : real
# face not found for file deepfake-detection-challenge-data/clrycekyst.mp4, frame 80
# extracting images for file cmbzllswnl.mp4 : real
# extracting images for file cmxcfkrjiv.mp4 : fake
# extracting images for file cnilkgvfei.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cnilkgvfei.mp4, frame 200
# extracting images for file coadfnerlk.mp4 : fake
# face not found for file deepfake-detection-challenge-data/coadfnerlk.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/coadfnerlk.mp4, frame 150
# extracting images for file cobjrlugvp.mp4 : real
# extracting images for file covdcysmbi.mp4 : fake
# extracting images for file cpjxareypw.mp4 : real
# extracting images for file cppdvdejkc.mp4 : real
# extracting images for file cprhtltsjp.mp4 : real
# extracting images for file cqfugiqupm.mp4 : fake
# extracting images for file cqhngvpgyi.mp4 : fake
# extracting images for file cqrskwiqng.mp4 : fake
# extracting images for file crezycjqyk.mp4 : real
# extracting images for file crktehraph.mp4 : fake
# extracting images for file crzfebnfgb.mp4 : fake
# face not found for file deepfake-detection-challenge-data/crzfebnfgb.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/crzfebnfgb.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/crzfebnfgb.mp4, frame 200
# extracting images for file cthdnahrkh.mp4 : fake
# extracting images for file ctpqeykqdp.mp4 : fake
# extracting images for file cttqtsjvgn.mp4 : fake
# extracting images for file ctzmavwror.mp4 : fake
# extracting images for file curpwogllm.mp4 : fake
# extracting images for file cuzrgrbvil.mp4 : fake
# extracting images for file cvaksbpssm.mp4 : fake
# extracting images for file cwbacdwrzo.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cwbacdwrzo.mp4, frame 200
# extracting images for file cwqlvzefpg.mp4 : fake
# extracting images for file cwrtyzndpx.mp4 : fake
# extracting images for file cwsbspfzck.mp4 : fake
# extracting images for file cwwandrkus.mp4 : fake
# extracting images for file cxfujlvsuw.mp4 : fake
# extracting images for file cxrfacemmq.mp4 : fake
# face not found for file deepfake-detection-challenge-data/cxrfacemmq.mp4, frame 200
# extracting images for file cxttmymlbn.mp4 : fake
# extracting images for file cyboodqqyr.mp4 : fake
# extracting images for file cycacemkmt.mp4 : fake
# extracting images for file cyclgfjdrv.mp4 : fake
# extracting images for file cyxlcuyznd.mp4 : real
# extracting images for file czfunozvwp.mp4 : fake
# extracting images for file czkdanyadc.mp4 : fake
# face not found for file deepfake-detection-challenge-data/czkdanyadc.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/czkdanyadc.mp4, frame 100
# extracting images for file czmqpxrqoh.mp4 : fake
# extracting images for file dafhtipaml.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dafhtipaml.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/dafhtipaml.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/dafhtipaml.mp4, frame 150
# extracting images for file dakiztgtnw.mp4 : real
# extracting images for file dakqwktlbi.mp4 : fake
# extracting images for file dbhoxkblzx.mp4 : fake
# extracting images for file dbhrpizyeq.mp4 : fake
# extracting images for file dbnygxtwek.mp4 : real
# extracting images for file dboxtiehng.mp4 : fake
# extracting images for file dbtbbhakdv.mp4 : real
# extracting images for file dbzcqmxzaj.mp4 : fake
# extracting images for file dbzpcjntve.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dbzpcjntve.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/dbzpcjntve.mp4, frame 200
# extracting images for file dcamvmuors.mp4 : fake
# extracting images for file dcuiiorugd.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dcuiiorugd.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/dcuiiorugd.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/dcuiiorugd.mp4, frame 200
# extracting images for file ddepeddixj.mp4 : real
# extracting images for file ddhfabwpuz.mp4 : fake
# extracting images for file ddjggcasdw.mp4 : fake
# extracting images for file ddpvuimigj.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ddpvuimigj.mp4, frame 150
# extracting images for file ddqccgmtka.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ddqccgmtka.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/ddqccgmtka.mp4, frame 150
# extracting images for file degpbqvcay.mp4 : fake
# face not found for file deepfake-detection-challenge-data/degpbqvcay.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/degpbqvcay.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/degpbqvcay.mp4, frame 150
# extracting images for file deywhkarol.mp4 : fake
# face not found for file deepfake-detection-challenge-data/deywhkarol.mp4, frame 200
# extracting images for file deyyistcrd.mp4 : fake
# extracting images for file dfbpceeaox.mp4 : fake
# extracting images for file dgmevclvzy.mp4 : fake
# extracting images for file dgxrqjdomn.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dgxrqjdomn.mp4, frame 80
# extracting images for file dgzklxjmix.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dgzklxjmix.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/dgzklxjmix.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/dgzklxjmix.mp4, frame 200
# extracting images for file dhcndnuwta.mp4 : real
# face not found for file deepfake-detection-challenge-data/dhcndnuwta.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/dhcndnuwta.mp4, frame 200
# extracting images for file dhcselezer.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dhcselezer.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/dhcselezer.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/dhcselezer.mp4, frame 200
# extracting images for file dhevettufk.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dhevettufk.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/dhevettufk.mp4, frame 100
# extracting images for file dhjmzhrcav.mp4 : fake
# extracting images for file dhkwmjxwrn.mp4 : fake
# extracting images for file dhoqofwoxa.mp4 : fake
# extracting images for file dhxctgyoqj.mp4 : real
# face not found for file deepfake-detection-challenge-data/dhxctgyoqj.mp4, frame 200
# extracting images for file diomeixhrg.mp4 : fake
# extracting images for file diopzaywor.mp4 : fake
# extracting images for file diqraixiov.mp4 : fake
# face not found for file deepfake-detection-challenge-data/diqraixiov.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/diqraixiov.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/diqraixiov.mp4, frame 150
# extracting images for file diuzrpqjli.mp4 : fake
# face not found for file deepfake-detection-challenge-data/diuzrpqjli.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/diuzrpqjli.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/diuzrpqjli.mp4, frame 200
# extracting images for file djvtbgwdcc.mp4 : fake
# extracting images for file djvutyvaio.mp4 : fake
# extracting images for file djxdyjopjd.mp4 : real
# extracting images for file dkdwxmtpuo.mp4 : fake
# extracting images for file dkhlttuvmx.mp4 : fake
# extracting images for file dkrvorliqc.mp4 : fake
# extracting images for file dkuayagnmc.mp4 : real
# extracting images for file dkwjwbwgey.mp4 : fake
# extracting images for file dkzvdrzcnr.mp4 : real
# extracting images for file dlpoieqvfb.mp4 : real
# face not found for file deepfake-detection-challenge-data/dlpoieqvfb.mp4, frame 200
# extracting images for file dlrsbscitn.mp4 : fake
# extracting images for file dnexlwbcxq.mp4 : fake
# extracting images for file dnhvalzvrt.mp4 : fake
# extracting images for file dntkzzzcdh.mp4 : fake
# extracting images for file dnyvfblxpm.mp4 : fake
# extracting images for file doanjploai.mp4 : fake
# extracting images for file dofusvhnib.mp4 : fake
# extracting images for file dozyddhild.mp4 : fake
# extracting images for file dptbnjnkdg.mp4 : fake
# extracting images for file dptrzdvwpg.mp4 : fake
# extracting images for file dqnyszdong.mp4 : fake
# extracting images for file dqppxmoqdl.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dqppxmoqdl.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/dqppxmoqdl.mp4, frame 200
# extracting images for file dqqtjcryjv.mp4 : fake
# extracting images for file dqswpjoepo.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dqswpjoepo.mp4, frame 80
# extracting images for file dqzreruvje.mp4 : fake
# extracting images for file drcyabprvt.mp4 : real
# extracting images for file drgjzlxzxj.mp4 : fake
# face not found for file deepfake-detection-challenge-data/drgjzlxzxj.mp4, frame 150
# extracting images for file drsakwyvqv.mp4 : fake
# extracting images for file drtbksnpol.mp4 : fake
# extracting images for file dsdoseflas.mp4 : fake
# extracting images for file dsgpbgsrdm.mp4 : fake
# extracting images for file dsjbknkujw.mp4 : real
# extracting images for file dsndhujjjb.mp4 : fake
# extracting images for file dtbpmdqvao.mp4 : fake
# extracting images for file dtocdfbwca.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dtocdfbwca.mp4, frame 200
# extracting images for file dubiroskqn.mp4 : fake
# extracting images for file dulanfulol.mp4 : fake
# extracting images for file duvyaxbzvp.mp4 : fake
# extracting images for file duycddgtrl.mp4 : real
# face not found for file deepfake-detection-challenge-data/duycddgtrl.mp4, frame 80
# extracting images for file duzuusuajr.mp4 : fake
# extracting images for file dvakowbgbt.mp4 : fake
# extracting images for file dvumqqhoac.mp4 : fake
# extracting images for file dwediigjit.mp4 : fake
# extracting images for file dxbqjxrhin.mp4 : real
# face not found for file deepfake-detection-challenge-data/dxbqjxrhin.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/dxbqjxrhin.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/dxbqjxrhin.mp4, frame 200
# extracting images for file dxuliowugt.mp4 : fake
# extracting images for file dxuplhwvig.mp4 : fake
# extracting images for file dzieklokdr.mp4 : fake
# extracting images for file dzqwgqewhu.mp4 : fake
# extracting images for file dzvyfiarrq.mp4 : fake
# extracting images for file dzwkmcwkwl.mp4 : fake
# face not found for file deepfake-detection-challenge-data/dzwkmcwkwl.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/dzwkmcwkwl.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/dzwkmcwkwl.mp4, frame 200
# extracting images for file dzyuwjkjui.mp4 : real
# extracting images for file eahlqmfvtj.mp4 : fake
# extracting images for file eajlrktemq.mp4 : fake
# extracting images for file ebchwmwayp.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ebchwmwayp.mp4, frame 200
# extracting images for file ebebgmtlcu.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ebebgmtlcu.mp4, frame 200
# extracting images for file ebeknhudxq.mp4 : fake
# extracting images for file ebkzwjgjhq.mp4 : fake
# extracting images for file ebywfrmhtd.mp4 : fake
# extracting images for file eckvhdusax.mp4 : real
# extracting images for file ecnihjlfyt.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ecnihjlfyt.mp4, frame 200
# extracting images for file ecujsjhscd.mp4 : real
# extracting images for file ecuvtoltue.mp4 : fake
# extracting images for file ecwaxgutkc.mp4 : fake
# extracting images for file eczrseixwq.mp4 : fake
# extracting images for file edyncaijwx.mp4 : real
# face not found for file deepfake-detection-challenge-data/edyncaijwx.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/edyncaijwx.mp4, frame 200
# extracting images for file eebrkicpry.mp4 : fake
# extracting images for file eebserckhh.mp4 : fake
# face not found for file deepfake-detection-challenge-data/eebserckhh.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/eebserckhh.mp4, frame 100
# extracting images for file eejswgycjc.mp4 : fake
# face not found for file deepfake-detection-challenge-data/eejswgycjc.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/eejswgycjc.mp4, frame 100
# extracting images for file eekozbeafq.mp4 : fake
# extracting images for file eepezmygaq.mp4 : fake
# extracting images for file eeyhxisdfh.mp4 : fake
# extracting images for file efdyrflcpg.mp4 : fake
# extracting images for file efwfxwwlbw.mp4 : real
# extracting images for file egbbcxcuqy.mp4 : fake
# extracting images for file eggbjzxnmg.mp4 : real
# face not found for file deepfake-detection-challenge-data/eggbjzxnmg.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/eggbjzxnmg.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/eggbjzxnmg.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/eggbjzxnmg.mp4, frame 200
# extracting images for file egghxjjmfg.mp4 : real
# extracting images for file ehbnclaukr.mp4 : fake
# extracting images for file ehccixxzoe.mp4 : real
# extracting images for file ehdkmxgtxh.mp4 : fake
# extracting images for file ehevsxtecd.mp4 : fake
# extracting images for file ehfiekigla.mp4 : fake
# extracting images for file ehieahnhte.mp4 : fake
# extracting images for file ehtdtkmmli.mp4 : real
# face not found for file deepfake-detection-challenge-data/ehtdtkmmli.mp4, frame 200
# extracting images for file eiriyukqqy.mp4 : fake
# extracting images for file eivxffliio.mp4 : fake
# extracting images for file eiwopxzjfn.mp4 : fake
# extracting images for file eixwxvxbbn.mp4 : fake
# extracting images for file ejkqesyvam.mp4 : fake
# extracting images for file ekcrtigpab.mp4 : real
# face not found for file deepfake-detection-challenge-data/ekcrtigpab.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/ekcrtigpab.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/ekcrtigpab.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/ekcrtigpab.mp4, frame 200
# extracting images for file ekhacizpah.mp4 : fake
# extracting images for file ekkdjkirzq.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ekkdjkirzq.mp4, frame 150
# extracting images for file elginszwtk.mp4 : fake
# extracting images for file ellavthztb.mp4 : real
# face not found for file deepfake-detection-challenge-data/ellavthztb.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/ellavthztb.mp4, frame 150
# face not found for file deepfake-detection-challenge-data/ellavthztb.mp4, frame 200
# extracting images for file elvvackpjh.mp4 : fake
# extracting images for file emaalmsonj.mp4 : fake
# extracting images for file emfbhytfhc.mp4 : fake
# extracting images for file emgjphonqb.mp4 : fake
# extracting images for file ensyyivobf.mp4 : fake
# face not found for file deepfake-detection-challenge-data/ensyyivobf.mp4, frame 80
# face not found for file deepfake-detection-challenge-data/ensyyivobf.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/ensyyivobf.mp4, frame 150
# extracting images for file eoewqcpbgt.mp4 : fake
# extracting images for file eprybmbpba.mp4 : fake
# extracting images for file epymyyiblu.mp4 : fake
# extracting images for file eqjscdagiv.mp4 : fake
# extracting images for file eqnoqyfquo.mp4 : real
# face not found for file deepfake-detection-challenge-data/eqnoqyfquo.mp4, frame 200
# extracting images for file eqvuznuwsa.mp4 : fake
# extracting images for file erlvuvjsjf.mp4 : real
# face not found for file deepfake-detection-challenge-data/erlvuvjsjf.mp4, frame 150
# extracting images for file erqgqacbqe.mp4 : fake
# extracting images for file errocgcham.mp4 : fake
# extracting images for file esckbnkkvb.mp4 : fake
# extracting images for file esgftaficx.mp4 : fake
# extracting images for file esnntzzajv.mp4 : fake
# extracting images for file esxrvsgpvb.mp4 : fake
# extracting images for file esyhwdfnxs.mp4 : fake
# extracting images for file esyrimvzsa.mp4 : fake
# face not found for file deepfake-detection-challenge-data/esyrimvzsa.mp4, frame 100
# extracting images for file etdcqxabww.mp4 : fake
# extracting images for file etejaapnxh.mp4 : fake
# extracting images for file etmcruaihe.mp4 : fake
# extracting images for file etohcvnzbj.mp4 : fake
# extracting images for file eudeqjhdfd.mp4 : real
# face not found for file deepfake-detection-challenge-data/eudeqjhdfd.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/eudeqjhdfd.mp4, frame 150
# extracting images for file eukvucdetx.mp4 : fake

# %% [markdown]
# ### Single file test

# %%
#get_faces_from_video_file(data_path + 'agqphdxmwt.mp4','fake')
# Out:
# face not found for file deepfake-detection-challenge-data/agqphdxmwt.mp4, frame 100
# face not found for file deepfake-detection-challenge-data/agqphdxmwt.mp4, frame 150
